# %% [markdown]
# # Imports

# %%
#Ticker Codes
from nsetools import Nse
# Raw Package
import numpy as np
import pandas as pd
#Data Source
import yfinance as yf

#pywidget
import ipywidgets as widget
# from IPython.display import display
import talib
# import trendln
# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt
import mplfinance as mpf
import datetime
import time

# from helper_functions import get_user_inputs, create_top_line, create_bottom_line, pull_price_data, plot_graph, isSupport, isResistance, isFarFromLevel, finding_signals_from_data, is_consolidating, is_breaking_out, technical_scoring_function, long_term_trend_scoring_function
from helper_functions import *
import helper_functions
import importlib
importlib.reload(helper_functions)
# %matplotlib inline

# %% [markdown]
# # Test Functions

# %% [markdown]
# Functions have been moved to "helper_functions.py"

# %%
# print('Select company name from drop down')
# nse = Nse()
# company_dict = nse.get_stock_codes()
# stock_ticker = widget.Dropdown(options=list(company_dict.values())[1:], value=  '20 Microns Limited', description='Stock:')
# stock_ticker

# %%
# #Backtesting function
# def backtest_function(mode = 'all', period = -2, live = 'no', csv_file = 'n50.csv', cur_thresh = 5):
#     tpm = 3 
#     if(mode == 'all'):
#         n50 = pd.read_csv(csv_file)
#         nifty50 = []
#         for t in n50['Symbol'].values:
#             nifty50.append(t+'.NS')
#         for t in nifty50:
#             ticker = t
#             #print(live)
#             data = pull_price_data(live, t, mode = 'scoring')
#             if(live == 'no'):
#                 data, levels, plot_sup_res = finding_signals_from_data(data, time_period_multiplier = 1)
#             else:
#                 data, levels, plot_sup_res = finding_signals_from_data(data, time_period_multiplier = tpm)
#             data = plot_graph(data, g_type, plot_sup_res, mode = 'scoring')
            
#             technical_score_column_list = []
#             for col in data.columns:
#                 if(col.startswith('final_score_technical')):
#                     technical_score_column_list.append(col)

#             backtest_df = data.copy()
#             long_profit_loss_calculation_df = pd.DataFrame(columns = ['Buy Date', 'Buy Price', 'Buy Signal', 
#                                                                       'isDone', 'Sell Date', 'Sell Price',
#                                                                       'Stop Loss', 'Target', 'Profit Percentage'])
#             if(live == 'yes'):
#                 technical_score_column_list.remove('final_score_technical_DOJI-')
#                 technical_score_column_list.remove('final_score_technical_DOJI+')
#             period = 2
#             for i in range(0 , len(data) - 1, 1):
#                 #Dropping doji for live data
#                 #if(live=='yes'):
#                 #    backtest_df.drop(columns = ['final_score_technical_DOJI-', 'final_score_technical_DOJI+'], inplace = True)

#                 #df of 2 days to match techincal scoring function      
#                 two_day_score = backtest_df.iloc[i:i+2]

#                 # Adjusting score for volume
#                 if(sum(two_day_score.drop(columns = ['final_score_technical_Volume']).sum(axis = 1).values ) > 0):
#                     if(two_day_score['final_score_technical_Volume'].isna().sum() != abs(period)):
#                         current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1)) + 1
#                     else:
#                         current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1))
#                 elif(sum(two_day_score.drop(columns = ['final_score_technical_Volume']).sum(axis = 1).values ) < 0):
#                     if(two_day_score['final_score_technical_Volume'].isna().sum() != abs(period)):
#                         current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1)) - 1
#                     else:
#                         current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1))
#                 current_market_price = two_day_score['Adj Close'].iloc[-1]
#                 current_date = two_day_score.index[-1]
#                 if(live == 'yes'):
#                     stop_loss_multiplier = 0.995
#                     target_multiplier = 1.01
#                 else:
#                     stop_loss_multiplier = 0.95
#                     target_multiplier = 1.1
#                 if(current_score >= cur_thresh):
#                     temp_row = {"Buy Date": current_date, "Buy Price": current_market_price, "Buy Signal" : current_score, 
#                                 "isDone" : 0, "Stop Loss": current_market_price * stop_loss_multiplier, 
#                                 "Target" : current_market_price * target_multiplier, "Threshold" : cur_thresh,
#                                "ticker" : t}
#                     long_profit_loss_calculation_df = long_profit_loss_calculation_df.append(temp_row, ignore_index = True)

#                 #Checking if price is above or below SL. Target
#                 if(len(long_profit_loss_calculation_df) > 0):
#                     to_be_checked_df = long_profit_loss_calculation_df[long_profit_loss_calculation_df['isDone'] == 0]
#                     for j in (to_be_checked_df.index):

#                         if(to_be_checked_df.loc[j]['Target'] < current_market_price):
#                             long_profit_loss_calculation_df.loc[j,"isDone"] = 1
#                             long_profit_loss_calculation_df.loc[j,"Sell Date"] = current_date
#                             long_profit_loss_calculation_df.loc[j,"Sell Price"] = current_market_price
#                             long_profit_loss_calculation_df.loc[j,"Profit Percentage"] = ((current_market_price - to_be_checked_df.loc[j]['Buy Price'])/to_be_checked_df.loc[j]['Buy Price'])*100
#                         elif(to_be_checked_df.loc[j]['Stop Loss'] > current_market_price):
#                             long_profit_loss_calculation_df.loc[j,"isDone"] = -1
#                             long_profit_loss_calculation_df.loc[j,"Sell Date"] = current_date
#                             long_profit_loss_calculation_df.loc[j,"Sell Price"] = current_market_price
#                             long_profit_loss_calculation_df.loc[j,"Profit Percentage"] = ((current_market_price - to_be_checked_df.loc[j]['Buy Price'])/to_be_checked_df.loc[j]['Buy Price'])*100
#             break
        
#         overall_profit = long_profit_loss_calculation_df['Profit Percentage'].sum()
#         good_calls = (len(long_profit_loss_calculation_df[long_profit_loss_calculation_df['Profit Percentage'] > 0]) - len(long_profit_loss_calculation_df[long_profit_loss_calculation_df['Profit Percentage'] < 0]))/len(long_profit_loss_calculation_df)
#         return(long_profit_loss_calculation_df, overall_profit, good_calls)
#     else:
#         print("else")
#         ticker = t = mode
#         data = pull_price_data(live, t, mode = 'scoring')
#         if(live == 'no'):
#             data, levels, plot_sup_res = finding_signals_from_data(data, time_period_multiplier = 1)
#         else:
#             data, levels, plot_sup_res = finding_signals_from_data(data, time_period_multiplier = tpm)
#         data = plot_graph(data, g_type, mode = 'scoring')

#         technical_score_column_list = []
#         for col in data.columns:
#             if(col.startswith('final_score_technical')):
#                 technical_score_column_list.append(col)

#         backtest_df = data.copy()
#         long_profit_loss_calculation_df = pd.DataFrame(columns = ['Buy Date', 'Buy Price', 'Buy Signal', 
#                                                                   'isDone', 'Sell Date', 'Sell Price',
#                                                                   'Stop Loss', 'Target', 'Profit Percentage'])
#         #print(long_profit_loss_calculation_df)
#         if(live == 'yes'):
#             technical_score_column_list.remove('final_score_technical_DOJI-')
#             technical_score_column_list.remove('final_score_technical_DOJI+')
#         period = 2
#         for i in range(0 , len(data) - 1, 1):
#             #Dropping doji for live data
#             #if(live=='yes'):
#             #    backtest_df.drop(columns = ['final_score_technical_DOJI-', 'final_score_technical_DOJI+'], inplace = True)

#             #df of 2 days to match techincal scoring function      
#             two_day_score = backtest_df.iloc[i:i+2]

#             # Adjusting score for volume
#             if(sum(two_day_score.drop(columns = ['final_score_technical_Volume']).sum(axis = 1).values ) > 0):
#                 if(two_day_score['final_score_technical_Volume'].isna().sum() != abs(period)):
#                     current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1)) + 1
#                 else:
#                     current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1))
#             elif(sum(two_day_score.drop(columns = ['final_score_technical_Volume']).sum(axis = 1).values ) < 0):
#                 if(two_day_score['final_score_technical_Volume'].isna().sum() != abs(period)):
#                     current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1)) - 1
#                 else:
#                     current_score = sum(two_day_score[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1))
#             current_market_price = two_day_score['Adj Close'].iloc[-1]
#             current_date = two_day_score.index[-1]
#             if(live == 'yes'):
#                 stop_loss_multiplier = 0.995
#                 target_multiplier = 1.01
#             else:
#                 stop_loss_multiplier = 0.95
#                 target_multiplier = 1.1
#             if(current_score >= cur_thresh):
#                 temp_row = {"Buy Date": current_date, "Buy Price": current_market_price, "Buy Signal" : current_score, 
#                             "isDone" : 0, "Stop Loss": current_market_price * stop_loss_multiplier, 
#                             "Target" : current_market_price * target_multiplier, "Threshold" : cur_thresh,
#                            "ticker" : t}
#                 long_profit_loss_calculation_df = long_profit_loss_calculation_df.append(temp_row, ignore_index = True)

#             #Checking if price is above or below SL. Target
#             if(len(long_profit_loss_calculation_df) > 0):
#                 to_be_checked_df = long_profit_loss_calculation_df[long_profit_loss_calculation_df['isDone'] == 0]
#                 for j in (to_be_checked_df.index):

#                     if(to_be_checked_df.loc[j]['Target'] < current_market_price):
#                         long_profit_loss_calculation_df.loc[j,"isDone"] = 1
#                         long_profit_loss_calculation_df.loc[j,"Sell Date"] = current_date
#                         long_profit_loss_calculation_df.loc[j,"Sell Price"] = current_market_price
#                         long_profit_loss_calculation_df.loc[j,"Profit Percentage"] = ((current_market_price - to_be_checked_df.loc[j]['Buy Price'])/to_be_checked_df.loc[j]['Buy Price'])*100
#                     elif(to_be_checked_df.loc[j]['Stop Loss'] > current_market_price):
#                         long_profit_loss_calculation_df.loc[j,"isDone"] = -1
#                         long_profit_loss_calculation_df.loc[j,"Sell Date"] = current_date
#                         long_profit_loss_calculation_df.loc[j,"Sell Price"] = current_market_price
#                         long_profit_loss_calculation_df.loc[j,"Profit Percentage"] = ((current_market_price - to_be_checked_df.loc[j]['Buy Price'])/to_be_checked_df.loc[j]['Buy Price'])*100
            
#         #print(len(long_profit_loss_calculation_df))
#         #print(long_profit_loss_calculation_df)
#         overall_profit = long_profit_loss_calculation_df['Profit Percentage'].sum()
#         good_calls = (len(long_profit_loss_calculation_df[long_profit_loss_calculation_df['Profit Percentage'] > 0]) - len(long_profit_loss_calculation_df[long_profit_loss_calculation_df['Profit Percentage'] < 0]))/len(long_profit_loss_calculation_df)
#     return(long_profit_loss_calculation_df, overall_profit, good_calls)

# %% [markdown]
# # Running functions

# %% [markdown]
# Shows indicators for given stock_ticker

# %%
#Getting data for single stock
live, g_type = get_user_inputs()
data = pull_price_data(live, stock_ticker = 'SIEMENS.NS')
print(data.index[-1])

if(live == 'yes'):
    print("Is Consolidating: ",is_consolidating(data, percentage=0.5))
else:
    print("Is Consolidating: ",is_consolidating(data))

    
if(live == 'yes'):
    print("Is Breaking Out: ",is_breaking_out(data, percentage=2))
else:
    print("Is Breaking Out: ",is_breaking_out(data))    

if(live == 'no' or live == 'max'):
    data, levels, plot_sup_res = finding_signals_from_data(data, time_period_multiplier = 1)
else:
    data, levels, plot_sup_res = finding_signals_from_data(data, time_period_multiplier = 3)
print(levels)
data = data[data['Close'].notna()]
plot_graph(data, g_type='line', mode = 'quick', plot_sup_res = plot_sup_res)
data = plot_graph(data, g_type, plot_sup_res = plot_sup_res)
# Out:
# Do you want live data?: yes/ no/ max
# no
# Enter period of months6
# Enter interval(1m, 1d, 1wk)1d
# [*********************100%***********************]  1 of 1 completed
# 2022-08-12 00:00:00
# Is Consolidating:  False
# Is Breaking Out:  False
# [(2, 2437.949951171875), (5, 2178.0), (27, 2529.0), (40, 2302.0), (90, 2712.0), (93, 2623.050048828125), (106, 2815.0)]

# %% [markdown]
# Dataframe returned from the technical_scoring_function

# %%
a, b = technical_scoring_function(mode = 'INTC', live = 'no')
a
# Out:
# [*********************100%***********************]  1 of 1 completed
#             final_score_technical_Volume  final_score_technical__RSI+  \
# Date
# 2022-07-14                           1.0                          NaN
# 2022-07-15                           NaN                          NaN
#
#             final_score_technical__RSI-  final_score_technical_MACD+  \
# Date
# 2022-07-14                          NaN                          NaN
# 2022-07-15                          NaN                          NaN
#
#             final_score_technical_MACD-  final_score_technical_BB+  \
# Date
# 2022-07-14                          NaN                        0.5
# 2022-07-15                          NaN                        NaN
#
#             final_score_technical_BB-  final_score_technical_supres+  \
# Date
# 2022-07-14                        NaN                            NaN
# 2022-07-15                        NaN                            NaN
#
#             final_score_technical_supres-  final_score_technical_CDL3INSIDE-  \
# Date
# 2022-07-14                            NaN                                NaN
# 2022-07-15                            NaN                                NaN
#
#             ...  final_score_technical_CDLSEPARATINGLINES-  \
# Date        ...
# 2022-07-14  ...                                        NaN
# 2022-07-15  ...                                        NaN
#
#             final_score_technical_CDL3INSIDE+  \
# Date
# 2022-07-14                                NaN
# 2022-07-15                                NaN
#
#             final_score_technical_CDL3OUTSIDE+  \
# Date
# 2022-07-14                                 NaN
# 2022-07-15                                 NaN
#
#             final_score_technical_CDLHAMMER+  \
# Date
# 2022-07-14                               NaN
# 2022-07-15                               NaN
#
#             final_score_technical_CDLINVERTEDHAMMER+  \
# Date
# 2022-07-14                                       NaN
# 2022-07-15                                       NaN
#
#             final_score_technical_CDLMORNINGSTAR+  \
# Date
# 2022-07-14                                    NaN
# 2022-07-15                                    NaN
#
#             final_score_technical_CDLSEPARATINGLINES+  \
# Date
# 2022-07-14                                        NaN
# 2022-07-15                                        NaN
#
#             final_score_technical_CDLUNIQUE3RIVER+  \
# Date
# 2022-07-14                                     NaN
# 2022-07-15                                     NaN
#
#             final_score_technical_DOJI-  final_score_technical_DOJI+
# Date
# 2022-07-14                          NaN                          NaN
# 2022-07-15                          NaN                          NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# # All scoring function

# %% [markdown]
# Give short term trend reversals. <br>
# Values over 4.0 can be a positive sign<br>
# Values below -4.0 can be a negative sign

# %%
#Scoring function (Gives Signal of Reversal)
# personal list = ['BIOCON.NS','COLPAL.NS']
start = datetime.datetime.now()
print(datetime.datetime.now())

pos_score_company, neg_score_company = technical_scoring_function(live = 'no', csv_file = 'n50.csv') #live, period, ticker as params
print('All Done')

pos_score_company = sorted(pos_score_company.items(), key=lambda x: x[1], reverse = True)
#neg_score_company = sorted(neg_score_company.items(), key=lambda x: x[1])


print(pos_score_company,'\n\n\n')
#print(neg_score_company)
print(datetime.datetime.now() - start)
# Out:
# 2022-08-14 16:18:48.694478
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# Error with CADILAHC.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MOTHERSUMI.NS: No data found, symbol may be delisted
# Error with MOTHERSUMI.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# All Done
# [('JUBLFOOD.NS', 6.5), ('SIEMENS.NS', 5.5), ('MUTHOOTFIN.NS', 4.5), ('PGHH.NS', 4.0), ('AUROPHARMA.NS', 3.5), ('LUPIN.NS', 3.5), ('PEL.NS', 3.5), ('IGL.NS', 3.17), ('HINDPETRO.NS', 3.0), ('ICICIGI.NS', 3.0), ('VEDL.NS', 3.0), ('ALKEM.NS', 2.0), ('DMART.NS', 2.0), ('BOSCHLTD.NS', 2.0), ('INDUSTOWER.NS', 2.0), ('PNB.NS', 2.0), ('GODREJCP.NS', 1.5), ('ADANIGREEN.NS', 1.0), ('BIOCON.NS', 1.0), ('DLF.NS', 1.0), ('DABUR.NS', 1.0), ('PETRONET.NS', 1.0), ('ACC.NS', 0.0), ('COLPAL.NS', 0.0), ('ADANIENT.NS', -0.33), ('ADANITRANS.NS', -0.33), ('BERGEPAINT.NS', -0.33), ('BANDHANBNK.NS', -1.0), ('AMBUJACEM.NS', -1.33), ('LTI.NS', -1.33), ('PIDILITIND.NS', -1.33), ('APOLLOHOSP.NS', -2.0), ('NAUKRI.NS', -2.0), ('YESBANK.NS', -2.0), ('INDIGO.NS', -3.0), ('ABBOTINDIA.NS', -3.5), ('MRF.NS', -3.5), ('TORNTPHARM.NS', -4.0)]
#
#
#
# 0:00:14.734709

# %% [markdown]
# Gives a long term trend<br>
# More positive scores can be associated with a relatively upwards trend<br>
# More negative scores can be associated with a relatively downwards trend

# %%
#Scoring function (Gives Longterm Trend)
print(datetime.datetime.now())

long_neg_score_company, long_pos_score_company = long_term_trend_scoring_function(live = 'no', csv_file = 'n50.csv') #live, period, ticker as params
print('All Done')

long_pos_score_company = sorted(long_pos_score_company.items(), key=lambda x: x[1], reverse = True)
long_neg_score_company = sorted(long_neg_score_company.items(), key=lambda x: x[1])


print(long_pos_score_company,'\n\n\n')
print(long_neg_score_company)
# Out:
# 2022-07-22 01:17:36.640276
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# Error with CADILAHC.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# All Done
# []
#
#
#
# [('BIOCON.NS', -7.0), ('BERGEPAINT.NS', -4.5), ('TORNTPHARM.NS', -2.83), ('DMART.NS', -2.0), ('AUROPHARMA.NS', -1.0), ('BANDHANBNK.NS', -0.6699999999999999), ('BAJAJHLDNG.NS', -0.33999999999999986), ('INDUSTOWER.NS', -0.33000000000000007), ('HDFCAMC.NS', 0.0), ('ADANIENT.NS', 0.17999999999999994), ('ALKEM.NS', 0.5), ('UBL.NS', 0.5299999999999995), ('GAIL.NS', 0.8300000000000001), ('ICICIGI.NS', 1.33), ('INDIGO.NS', 1.33), ('ICICIPRULI.NS', 1.5), ('LUPIN.NS', 1.5), ('NMDC.NS', 1.9700000000000006), ('NAUKRI.NS', 2.0), ('PNB.NS', 2.33), ('MCDOWELL-N.NS', 2.5), ('APOLLOHOSP.NS', 2.67), ('MUTHOOTFIN.NS', 2.9800000000000004), ('IGL.NS', 3.0), ('MOTHERSUMI.NS', 3.0), ('ADANIGREEN.NS', 3.17), ('DLF.NS', 3.17), ('AMBUJACEM.NS', 3.5), ('JUBLFOOD.NS', 3.5), ('LTI.NS', 3.5), ('SIEMENS.NS', 3.539999999999999), ('HINDPETRO.NS', 3.6500000000000004), ('PEL.NS', 4.0), ('ACC.NS', 4.33), ('MRF.NS', 4.35), ('HAVELLS.NS', 4.68), ('ADANITRANS.NS', 4.699999999999999), ('VEDL.NS', 4.950000000000001), ('PIDILITIND.NS', 5.33), ('SBICARD.NS', 5.35), ('MARICO.NS', 5.5), ('BOSCHLTD.NS', 5.51), ('ABBOTINDIA.NS', 6.34), ('PGHH.NS', 6.5), ('YESBANK.NS', 7.34), ('PETRONET.NS', 7.83), ('COLPAL.NS', 8.5), ('DABUR.NS', 9.01), ('GODREJCP.NS', 11.17)]

# %% [markdown]
# # My list

# %% [markdown]
# The above 2 functions can also be run with a specific list of tickers.

# %%
#Scoring function (Gives Signal of Reversal)
# personal list = ['BIOCON.NS','COLPAL.NS']
pos_score_company, neg_score_company = technical_scoring_function(mode = "list") #live, period, ticker as params
print('All Done')

pos_score_company = sorted(pos_score_company.items(), key=lambda x: x[1], reverse = True)
neg_score_company = sorted(neg_score_company.items(), key=lambda x: x[1])


print(pos_score_company,'\n\n\n')
print(neg_score_company)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# All Done
# [('BIOCON.NS', 0.0), ('COLPAL.NS', 0.0)]
#
#
#
# []

# %%
#Scoring function (Gives Longterm Trend)
neg_score_company, pos_score_company = long_term_trend_scoring_function(mode = 'list') #live, period, ticker as params
print('All Done')

pos_score_company = sorted(pos_score_company.items(), key=lambda x: x[1], reverse = True)
neg_score_company = sorted(neg_score_company.items(), key=lambda x: x[1])


print(pos_score_company,'\n\n\n')
print(neg_score_company)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# All Done
# []
#
#
#
# [('BIOCON.NS', -0.5), ('COLPAL.NS', 4.5)]

# %% [markdown]
# ### Loops for continuous running for live data

# %% [markdown]
# Works for live data when markets are open, else will show the same outputs everytime.

# %%
def update():
    import time
    from IPython.display import clear_output
    while True:
        pos_score_company, neg_score_company = technical_scoring_function( live = 'yes', csv_file = 'n50.csv') #live, period, ticker as params
        #pos_score_company = sorted(pos_score_company.items(), key=lambda x: x[1], reverse = True)
        #neg_score_company = sorted(neg_score_company.items(), key=lambda x: x[1])

        #clear_output(wait=True)
        print(pos_score_company, datetime.datetime.now().strftime("%H:%M:%S"))
        #print(neg_score_company)
        time.sleep(29)

update()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Error with ACC.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Error with APOLLOHOSP.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Error with BIOCON.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# Error with CADILAHC.NS
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-afef9bdc57c1> in <module>
#      12         time.sleep(29)
#      13
# ---> 14 update()
#
# <ipython-input-25-afef9bdc57c1> in update()
#       3     from IPython.display import clear_output
#       4     while True:
# ----> 5         pos_score_company, neg_score_company = technical_scoring_function( live = 'yes', csv_file = 'n50.csv') #live, period, ticker as params
#       6         #pos_score_company = sorted(pos_score_company.items(), key=lambda x: x[1], reverse = True)
#       7         #neg_score_company = sorted(neg_score_company.items(), key=lambda x: x[1])
#
# E:\Stock Market Project\Stock-Scoring\helper_functions.py in technical_scoring_function(mode, period, live, csv_file)
#     396             ticker = t
#     397             #print(live)
# --> 398             data = pull_price_data(live, t, mode = 'scoring')
#     399             try:
#     400                 if(live == 'no'):
#
# E:\Stock Market Project\Stock-Scoring\helper_functions.py in pull_price_data(live, stock_ticker, mode)
#      63         data = yf.download(tickers=ticker, start = start, end =end, interval=interval)
#      64     elif(live == 'yes'):
# ---> 65         data = yf.download(tickers=ticker, period = '2d', interval='1m')
#      66         data.set_index(pd.Series(data.index).apply(lambda x: x.replace(tzinfo=None)), inplace = True)
#      67         data.index.name = 'Date'
#
# ~\anaconda3\lib\site-packages\yfinance\multi.py in download(tickers, start, end, actions, threads, group_by, auto_adjust, back_adjust, progress, period, show_errors, interval, prepost, proxy, rounding, **kwargs)
#      95                                    rounding=rounding)
#      96         while len(shared._DFS) < len(tickers):
# ---> 97             _time.sleep(0.01)
#      98
#      99     # download synchronously
#
# KeyboardInterrupt:

# %%
# 
def update():
    import time
    from IPython.display import clear_output
    while True:
        pos_score_company, neg_score_company = long_term_trend_scoring_function(mode = "list", live = 'yes') #live, period, ticker as params
        #pos_score_company = sorted(pos_score_company.items(), key=lambda x: x[1], reverse = True)
        #neg_score_company = sorted(neg_score_company.items(), key=lambda x: x[1])

        #clear_output(wait=True)
        print(pos_score_company, datetime.datetime.now().strftime("%H:%M:%S"))
        #print(neg_score_company)
        time.sleep(3)

update()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'BIOCON.NS': 1.5, 'COLPAL.NS': 9.0} 14:53:46
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'BIOCON.NS': 1.5, 'COLPAL.NS': 9.0} 14:53:51
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'BIOCON.NS': 1.5, 'COLPAL.NS': 9.0} 14:53:55
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'BIOCON.NS': 1.5, 'COLPAL.NS': 9.0} 14:54:00
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'BIOCON.NS': 1.5, 'COLPAL.NS': 9.0} 14:54:05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-329fdf81e5eb> in <module>
#      12         time.sleep(3)
#      13
# ---> 14 update()
#
# <ipython-input-38-329fdf81e5eb> in update()
#      10         print(pos_score_company, datetime.datetime.now().strftime("%H:%M:%S"))
#      11         #print(neg_score_company)
# ---> 12         time.sleep(3)
#      13
#      14 update()
#
# KeyboardInterrupt:

# %% [markdown]
# # Backtesting

# %%
backtest_dict = {}
for i in range(2, 31):
    print(i, "\n\n\n")
    td = backtest(period = i, csv_file = 'n50.csv')
    avg = sum(list(td.values())) / len(list(td.values()))
    backtest_dict[i] = [avg, td]
# Out:
# 2
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 3
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 4
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 5
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 6
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 7
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 8
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 9
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 10
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 11
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4921
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4523
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 12
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1615
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4921
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4523
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# ...
# 28
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3238
# Could not perform 3248
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1615
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4968
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6574
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1308
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4947
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4501
# Could not perform 4503
# Could not perform 4512
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4966
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3677
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4961
# Could not perform 4965
# Could not perform 4970
# Could not perform 4971
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4965
# Could not perform 4974
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6648
# Could not perform 6658
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1169
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1425
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2348
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3060
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1457
# Could not perform 1466
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6057
# Could not perform 6058
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4921
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2746
# Could not perform 2750
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4523
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6644
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 566
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 5883
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4968
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3431
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6426
# Could not perform 6429
# Could not perform 6430
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 29
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3238
# Could not perform 3248
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1615
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4968
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6574
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1308
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4947
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4501
# Could not perform 4503
# Could not perform 4512
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4966
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3677
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4961
# Could not perform 4965
# Could not perform 4970
# Could not perform 4971
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4965
# Could not perform 4974
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6648
# Could not perform 6658
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1169
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1425
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2348
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3060
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1457
# Could not perform 1466
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6057
# Could not perform 6058
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4921
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2746
# Could not perform 2750
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4523
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6644
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 566
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 5883
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4968
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3431
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6426
# Could not perform 6429
# Could not perform 6430
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# 30
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3238
# Could not perform 3248
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1615
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4968
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6574
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1308
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4947
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4501
# Could not perform 4503
# Could not perform 4512
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4966
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3677
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4961
# Could not perform 4965
# Could not perform 4970
# Could not perform 4971
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4965
# Could not perform 4974
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6648
# Could not perform 6658
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1169
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1425
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2348
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3060
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1457
# Could not perform 1466
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6057
# Could not perform 6058
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4921
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2746
# Could not perform 2750
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4523
# Could not perform 4527
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6644
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 566
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 5883
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4968
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3431
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6426
# Could not perform 6429
# Could not perform 6430
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done

# %%
avgs = [ ]
ns = []
i = 0
for el in list(backtest_dict.values()):
    avgs.append(el[0])
    ns.append(i)
    i += 1
plt.plot(ns, avgs)
plt.title("Days Held vs Profit for Nifty 50")
plt.xlabel("Days Held")
plt.ylabel("Profit %")
plt.show()

# %%
backtest_dict = {}
for i in range(2, 31):
    print(i, "\n\n\n")
    td = backtest(period = i, csv_file = 'n200.csv')
    avg = sum(list(td.values())) / len(list(td.values()))
    backtest_dict[i] = [avg, td]

avgs = [ ]
ns = []
i = 0
for el in list(backtest_dict.values()):
    avgs.append(el[0])
    ns.append(i)
    i += 1
plt.plot(ns, avgs)
plt.title("Days Held vs Profit for Nifty 200")
plt.xlabel("Days Held")
plt.ylabel("Profit %")
plt.show()
# Out:
# 2
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# AARTIIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIPORTS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ATGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABCAPITAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABFRL.NS Done
# [*********************100%***********************]  1 of 1 completed
# AJANTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APLLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMARAJABAT.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOTYRE.NS Done
# [*********************100%***********************]  1 of 1 completed
# ASHOKLEY.NS Done
# [*********************100%***********************]  1 of 1 completed
# ASIANPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# AXISBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJ-AUTO.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJFINANCE.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJFINSV.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BALKRISIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4985
# BANKBARODA.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANKINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# BATAINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BHARATFORG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BHEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BPCL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BHARTIARTL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# BBTC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# BRITANNIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : -1 if(x==x) else x) #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : 1 if(x==x) else x)  #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI-'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] > 0 ),-1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI+'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] < 0 ),1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI-'] = data['final_score_technical_DOJI-']
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI+'] = data['final_score_technical_DOJI+']
# C:\Users\Abhishek\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:868: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_Volume'] = data['final_score_technical_Volume'] * data[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1).apply(check_total_for_getting_sign_of_volume)
# CESC.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# CANBK.NS Done
# [*********************100%***********************]  1 of 1 completed
# CASTROLIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# CHOLAFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# CIPLA.NS Done
# [*********************100%***********************]  1 of 1 completed
# CUB.NS Done
# [*********************100%***********************]  1 of 1 completed
# COALINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4422
# COFORGE.NS Done
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# CONCOR.NS Done
# [*********************100%***********************]  1 of 1 completed
# COROMANDEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# CROMPTON.NS Done
# [*********************100%***********************]  1 of 1 completed
# CUMMINSIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# DALBHARAT.NS Done
# [*********************100%***********************]  1 of 1 completed
# DEEPAKNTR.NS Done
# [*********************100%***********************]  1 of 1 completed
# DHANI.NS Done
# [*********************100%***********************]  1 of 1 completed
# DIVISLAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# DIXON.NS Done
# [*********************100%***********************]  1 of 1 completed
# LALPATHLAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# DRREDDY.NS Done
# [*********************100%***********************]  1 of 1 completed
# EICHERMOT.NS Done
# [*********************100%***********************]  1 of 1 completed
# EMAMILTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# ENDURANCE.NS Done
# [*********************100%***********************]  1 of 1 completed
# ESCORTS.NS Done
# [*********************100%***********************]  1 of 1 completed
# EXIDEIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# FEDERALBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# FORTIS.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GMRINFRA.NS Done
# [*********************100%***********************]  1 of 1 completed
# GLENMARK.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJAGRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJPROP.NS Done
# [*********************100%***********************]  1 of 1 completed
# GRASIM.NS Done
# [*********************100%***********************]  1 of 1 completed
# GUJGASLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# GSPL.NS Done
# [*********************100%***********************]  1 of 1 completed
# HCLTECH.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6676
# HDFCBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCLIFE.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HEROMOTOCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDALCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDUNILVR.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDZINC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ISEC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IDFCFIRSTB.NS Done
# [*********************100%***********************]  1 of 1 completed
# ITC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IBULHSGFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIAMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDHOTEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# IOC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IRCTC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSINDBK.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INFY.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# IPCALAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS Done
# [*********************100%***********************]  1 of 1 completed
# JSWSTEEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# JINDALSTEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# KOTAKBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# L&TFH.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTTS.NS Done
# [*********************100%***********************]  1 of 1 completed
# LICHSGFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LT.NS Done
# [*********************100%***********************]  1 of 1 completed
# LAURUSLABS.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# M&MFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# M&M.NS Done
# [*********************100%***********************]  1 of 1 completed
# MANAPPURAM.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARUTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6662
# MFSL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MINDTREE.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MPHASIS.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NATCOPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# NTPC.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAVINFLUOR.NS Done
# [*********************100%***********************]  1 of 1 completed
# NESTLEIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1164
# NAM-INDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# OBEROIRLTY.NS Done
# [*********************100%***********************]  1 of 1 completed
# ONGC.NS Done
# [*********************100%***********************]  1 of 1 completed
# OIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PAGEIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PFIZER.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# POLYCAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# PFC.NS Done
# [*********************100%***********************]  1 of 1 completed
# POWERGRID.NS Done
# [*********************100%***********************]  1 of 1 completed
# PRESTIGE.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# RBLBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# RECLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# RELIANCE.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBILIFE.NS Done
# [*********************100%***********************]  1 of 1 completed
# SRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : -1 if(x==x) else x) #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : 1 if(x==x) else x)  #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI-'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] > 0 ),-1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI+'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] < 0 ),1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI-'] = data['final_score_technical_DOJI-']
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI+'] = data['final_score_technical_DOJI+']
# C:\Users\Abhishek\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:868: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_Volume'] = data['final_score_technical_Volume'] * data[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1).apply(check_total_for_getting_sign_of_volume)
# SANOFI.NS Done
# [*********************100%***********************]  1 of 1 completed
# SHREECEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# SRTRANSFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# SAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# SUNPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# SUNTV.NS Done
# [*********************100%***********************]  1 of 1 completed
# SYNGENE.NS Done
# [*********************100%***********************]  1 of 1 completed
# TVSMOTOR.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATACHEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# TCS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATACONSUM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4985
# TATAELXSI.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATAMOTORS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATAPOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATASTEEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# TECHM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4980
# RAMCOCEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# TITAN.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# TORNTPOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# TRENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# UPL.NS Done
# [*********************100%***********************]  1 of 1 completed
# ULTRACEMCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# UNIONBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# UBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VGUARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# VBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# IDEA.NS Done
# [*********************100%***********************]  1 of 1 completed
# VOLTAS.NS Done
# [*********************100%***********************]  1 of 1 completed
# WHIRLPOOL.NS Done
# [*********************100%***********************]  1 of 1 completed
# WIPRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# ZEEL.NS Done
# 3
#
#
#
# [*********************100%***********************]  1 of 1 completed
# ACC.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# AARTIIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIGREEN.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANIPORTS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ATGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# ADANITRANS.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABCAPITAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# ABFRL.NS Done
# [*********************100%***********************]  1 of 1 completed
# AJANTPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APLLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMARAJABAT.NS Done
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS Done
# [*********************100%***********************]  1 of 1 completed
# APOLLOTYRE.NS Done
# [*********************100%***********************]  1 of 1 completed
# ASHOKLEY.NS Done
# [*********************100%***********************]  1 of 1 completed
# ASIANPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# DMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# AXISBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJ-AUTO.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJFINANCE.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJFINSV.NS Done
# [*********************100%***********************]  1 of 1 completed
# BAJAJHLDNG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BALKRISIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4985
# BANKBARODA.NS Done
# [*********************100%***********************]  1 of 1 completed
# BANKINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# BATAINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS Done
# [*********************100%***********************]  1 of 1 completed
# BEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BHARATFORG.NS Done
# [*********************100%***********************]  1 of 1 completed
# BHEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BPCL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BHARTIARTL.NS Done
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS Done
# [*********************100%***********************]  1 of 1 completed
# BBTC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4986
# BOSCHLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# BRITANNIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : -1 if(x==x) else x) #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : 1 if(x==x) else x)  #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI-'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] > 0 ),-1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI+'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] < 0 ),1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI-'] = data['final_score_technical_DOJI-']
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI+'] = data['final_score_technical_DOJI+']
# C:\Users\Abhishek\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:868: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_Volume'] = data['final_score_technical_Volume'] * data[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1).apply(check_total_for_getting_sign_of_volume)
# CESC.NS Done
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CADILAHC.NS: No data found, symbol may be delisted
# CADILAHC.NS Could not get data
# [*********************100%***********************]  1 of 1 completed
# CANBK.NS Done
# [*********************100%***********************]  1 of 1 completed
# CASTROLIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# CHOLAFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# CIPLA.NS Done
# [*********************100%***********************]  1 of 1 completed
# CUB.NS Done
# [*********************100%***********************]  1 of 1 completed
# COALINDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4422
# COFORGE.NS Done
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# CONCOR.NS Done
# [*********************100%***********************]  1 of 1 completed
# COROMANDEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# CROMPTON.NS Done
# [*********************100%***********************]  1 of 1 completed
# CUMMINSIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# DLF.NS Done
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS Done
# [*********************100%***********************]  1 of 1 completed
# DALBHARAT.NS Done
# [*********************100%***********************]  1 of 1 completed
# DEEPAKNTR.NS Done
# [*********************100%***********************]  1 of 1 completed
# DHANI.NS Done
# [*********************100%***********************]  1 of 1 completed
# DIVISLAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# DIXON.NS Done
# [*********************100%***********************]  1 of 1 completed
# LALPATHLAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# DRREDDY.NS Done
# [*********************100%***********************]  1 of 1 completed
# EICHERMOT.NS Done
# [*********************100%***********************]  1 of 1 completed
# EMAMILTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# ENDURANCE.NS Done
# [*********************100%***********************]  1 of 1 completed
# ESCORTS.NS Done
# [*********************100%***********************]  1 of 1 completed
# EXIDEIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# FEDERALBNK.NS Done
# [*********************100%***********************]  1 of 1 completed
# FORTIS.NS Done
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# GMRINFRA.NS Done
# [*********************100%***********************]  1 of 1 completed
# GLENMARK.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJAGRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS Done
# [*********************100%***********************]  1 of 1 completed
# GODREJIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3097
# GODREJPROP.NS Done
# [*********************100%***********************]  1 of 1 completed
# GRASIM.NS Done
# [*********************100%***********************]  1 of 1 completed
# GUJGASLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# GSPL.NS Done
# [*********************100%***********************]  1 of 1 completed
# HCLTECH.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6674
# Could not perform 6676
# HDFCBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCLIFE.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# HEROMOTOCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDALCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDUNILVR.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDZINC.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ISEC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IDFCFIRSTB.NS Done
# [*********************100%***********************]  1 of 1 completed
# ITC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IBULHSGFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIAMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDHOTEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# IOC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IRCTC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDUSINDBK.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS Done
# [*********************100%***********************]  1 of 1 completed
# INFY.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS Done
# [*********************100%***********************]  1 of 1 completed
# IPCALAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS Done
# [*********************100%***********************]  1 of 1 completed
# JSWSTEEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# JINDALSTEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3073
# JUBLFOOD.NS Done
# [*********************100%***********************]  1 of 1 completed
# KOTAKBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# L&TFH.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTTS.NS Done
# [*********************100%***********************]  1 of 1 completed
# LICHSGFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# LTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# LT.NS Done
# [*********************100%***********************]  1 of 1 completed
# LAURUSLABS.NS Done
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# MRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# MGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# M&MFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# M&M.NS Done
# [*********************100%***********************]  1 of 1 completed
# MANAPPURAM.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS Done
# [*********************100%***********************]  1 of 1 completed
# MARUTI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6662
# MFSL.NS Done
# [*********************100%***********************]  1 of 1 completed
# MINDTREE.NS Done
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS Done
# [*********************100%***********************]  1 of 1 completed
# MPHASIS.NS Done
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# NATCOPHARM.NS Done
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS Done
# [*********************100%***********************]  1 of 1 completed
# NTPC.NS Done
# [*********************100%***********************]  1 of 1 completed
# NAVINFLUOR.NS Done
# [*********************100%***********************]  1 of 1 completed
# NESTLEIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1164
# NAM-INDIA.NS Done
# [*********************100%***********************]  1 of 1 completed
# OBEROIRLTY.NS Done
# [*********************100%***********************]  1 of 1 completed
# ONGC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3159
# OIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PAGEIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS Done
# [*********************100%***********************]  1 of 1 completed
# PFIZER.NS Done
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS Done
# [*********************100%***********************]  1 of 1 completed
# PEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# POLYCAB.NS Done
# [*********************100%***********************]  1 of 1 completed
# PFC.NS Done
# [*********************100%***********************]  1 of 1 completed
# POWERGRID.NS Done
# [*********************100%***********************]  1 of 1 completed
# PRESTIGE.NS Done
# [*********************100%***********************]  1 of 1 completed
# PGHH.NS Done
# [*********************100%***********************]  1 of 1 completed
# PNB.NS Done
# [*********************100%***********************]  1 of 1 completed
# RBLBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# RECLTD.NS Done
# [*********************100%***********************]  1 of 1 completed
# RELIANCE.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBILIFE.NS Done
# [*********************100%***********************]  1 of 1 completed
# SRF.NS Done
# [*********************100%***********************]  1 of 1 completed
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : -1 if(x==x) else x) #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_'+candlestick] = temp['data'].apply(lambda x : 1 if(x==x) else x)  #final score for candlesticks to sum
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI-'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] > 0 ),-1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI+'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] < 0 ),1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI-'] = data['final_score_technical_DOJI-']
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI+'] = data['final_score_technical_DOJI+']
# C:\Users\Abhishek\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:868: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_Volume'] = data['final_score_technical_Volume'] * data[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1).apply(check_total_for_getting_sign_of_volume)
# SANOFI.NS Done
# [*********************100%***********************]  1 of 1 completed
# SHREECEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# SRTRANSFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS Done
# [*********************100%***********************]  1 of 1 completed
# SBIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# SAIL.NS Done
# [*********************100%***********************]  1 of 1 completed
# SUNPHARMA.NS Done
# [*********************100%***********************]  1 of 1 completed
# SUNTV.NS Done
# [*********************100%***********************]  1 of 1 completed
# SYNGENE.NS Done
# [*********************100%***********************]  1 of 1 completed
# TVSMOTOR.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATACHEM.NS Done
# [*********************100%***********************]  1 of 1 completed
# TCS.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATACONSUM.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4985
# TATAELXSI.NS Done
# [*********************100%***********************]  1 of 1 completed
# TATAMOTORS.NS Done
# ...
# Could not perform 6656
# Could not perform 6665
# Could not perform 6674
# Could not perform 6676
# HDFCBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# HDFCLIFE.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4965
# HEROMOTOCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6658
# HINDALCO.NS Done
# [*********************100%***********************]  1 of 1 completed
# HAL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6648
# Could not perform 6658
# HINDPETRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6656
# HINDUNILVR.NS Done
# [*********************100%***********************]  1 of 1 completed
# HINDZINC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4471
# Could not perform 4475
# HDFC.NS Done
# [*********************100%***********************]  1 of 1 completed
# ICICIBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1169
# ICICIGI.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1425
# ICICIPRULI.NS Done
# [*********************100%***********************]  1 of 1 completed
# ISEC.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1642
# IDFCFIRSTB.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6654
# ITC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IBULHSGFIN.NS Done
# [*********************100%***********************]  1 of 1 completed
# INDIAMART.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4967
# INDHOTEL.NS Done
# [*********************100%***********************]  1 of 1 completed
# IOC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IRCTC.NS Done
# [*********************100%***********************]  1 of 1 completed
# IGL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 
L.NS Done
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS Done
# [*********************100%***********************]  1 of 1 completed
# VGUARD.NS Done
# [*********************100%***********************]  1 of 1 completed
# VBL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6426
# Could not perform 6429
# Could not perform 6430
# VEDL.NS Done
# [*********************100%***********************]  1 of 1 completed
# IDEA.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 4983
# VOLTAS.NS Done
# [*********************100%***********************]  1 of 1 completed
# WHIRLPOOL.NS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6549
# Could not perform 6568
# WIPRO.NS Done
# [*********************100%***********************]  1 of 1 completed
# YESBANK.NS Done
# [*********************100%***********************]  1 of 1 completed
# ZEEL.NS Done

# %%
backtest_dict = {}
for i in range(2, 31):
    print(i, "\n\n\n")
    td = backtest(period = i, csv_file = 'NASDAQ 100 Tickers.csv')
    avg = sum(list(td.values())) / len(list(td.values()))
    backtest_dict[i] = [avg, td]

avgs = [ ]
ns = []
i = 0
for el in list(backtest_dict.values()):
    avgs.append(el[0])
    ns.append(i)
    i += 1
plt.plot(ns, avgs)
plt.title("Days Held vs Profit for NASDAQ 100 ")
plt.xlabel("Days Held")
plt.ylabel("Profit %")
plt.show()
# Out:
# 2
#
#
#
# [*********************100%***********************]  1 of 1 completed
# AAPL Done
# [*********************100%***********************]  1 of 1 completed
# ABNB Done
# [*********************100%***********************]  1 of 1 completed
# ADBE Done
# [*********************100%***********************]  1 of 1 completed
# ADI Done
# [*********************100%***********************]  1 of 1 completed
# ADP Done
# [*********************100%***********************]  1 of 1 completed
# ADSK Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 15242
# AEP Done
# [*********************100%***********************]  1 of 1 completed
# ALGN Done
# [*********************100%***********************]  1 of 1 completed
# AMAT Done
# [*********************100%***********************]  1 of 1 completed
# AMD Done
# [*********************100%***********************]  1 of 1 completed
# AMGN Done
# [*********************100%***********************]  1 of 1 completed
# AMZN Done
# [*********************100%***********************]  1 of 1 completed
# ANSS Done
# [*********************100%***********************]  1 of 1 completed
# ASML Done
# [*********************100%***********************]  1 of 1 completed
# ATVI Done
# [*********************100%***********************]  1 of 1 completed
# AVGO Done
# [*********************100%***********************]  1 of 1 completed
# AZN Done
# [*********************100%***********************]  1 of 1 completed
# BIDU Done
# [*********************100%***********************]  1 of 1 completed
# BIIB Done
# [*********************100%***********************]  1 of 1 completed
# BKNG Done
# [*********************100%***********************]  1 of 1 completed
# CDNS Done
# [*********************100%***********************]  1 of 1 completed
# CEG division error during appending
# [*********************100%***********************]  1 of 1 completed
# CHTR Done
# [*********************100%***********************]  1 of 1 completed
# CMCSA Done
# [*********************100%***********************]  1 of 1 completed
# COST Done
# [*********************100%***********************]  1 of 1 completed
# CPRT Done
# [*********************100%***********************]  1 of 1 completed
# CRWD Done
# [*********************100%***********************]  1 of 1 completed
# CSCO Done
# [*********************100%***********************]  1 of 1 completed
# CSX Done
# [*********************100%***********************]  1 of 1 completed
# CTAS Done
# [*********************100%***********************]  1 of 1 completed
# CTSH Done
# [*********************100%***********************]  1 of 1 completed
# DDOG Done
# [*********************100%***********************]  1 of 1 completed
# DLTR Done
# [*********************100%***********************]  1 of 1 completed
# DOCU Done
# [*********************100%***********************]  1 of 1 completed
# DXCM Done
# [*********************100%***********************]  1 of 1 completed
# EA Done
# [*********************100%***********************]  1 of 1 completed
# EBAY Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 
,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_DOJI+'] = np.where((data[['CDLDOJI','CDLDOJISTAR','CDLDRAGONFLYDOJI']].abs().sum(axis = 1) >0) & (data['current_trend'] < 0 ),1,np.nan)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI-'] = data['final_score_technical_DOJI-']
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['graph_DOJI+'] = data['final_score_technical_DOJI+']
# C:\Users\Abhishek\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:868: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['final_score_technical_Volume'] = data['final_score_technical_Volume'] * data[technical_score_column_list].drop(columns = ['final_score_technical_Volume']).sum(axis = 1).apply(check_total_for_getting_sign_of_volume)
# NVDA Done
# [*********************100%***********************]  1 of 1 completed
# NXPI Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7270
# Could not perform 7285
# ODFL Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1318
# Could not perform 1329
# OKTA Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7334
# ORLY Done
# [*********************100%***********************]  1 of 1 completed
# PANW Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 9767
# Could not perform 9770
# Could not perform 9786
# PAYX Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 10653
# Could not perform 10655
# PCAR Done
# [*********************100%***********************]  1 of 1 completed
# PDD Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 12615
# Could not perform 12620
# PEP Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1770
# PYPL Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7691
# QCOM Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7867
# Could not perform 7874
# REGN Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 9293
# ROST Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7554
# SBUX Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 5350
# SGEN Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6974
# SIRI Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7647
# Could not perform 7655
# SNPS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2562
# SPLK Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 9365
# Could not perform 9376
# SWKS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 1640
# Could not perform 1662
# Could not perform 1663
# TEAM Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3817
# Could not perform 3819
# Could not perform 3822
# TMUS Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3012
# Could not perform 3015
# Could not perform 3018
# TSLA Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 12632
# TXN Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 3194
# Could not perform 3197
# VRSK Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 6140
# VRSN Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 7804
# VRTX Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 10658
# Could not perform 10670
# WBA Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 2438
# WDAY Done
# [*********************100%***********************]  1 of 1 completed
# Could not perform 12433
# Could not perform 12437
# Could not perform 12453
# XEL Done
# [*********************100%***********************]  1 of 1 completed
# ZM Done
# [*********************100%***********************]  1 of 1 completed
# ZS Done

# %% [markdown]
# # Fundamentals

# %%
start = datetime.datetime.now()
combined_financial_ratio_df = create_df_of_financial_ratios('n500.csv', quarterly = 'yes')
print('Time taken : ',datetime.datetime.now() - start)
# Out:
# 1 3MINDIA.NS
# 2 ABB.NS
# 3 POWERINDIA.NS
# 4 ACC.NS
# 5 AIAENG.NS
# 6 APLAPOLLO.NS
# 7 AUBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 8 AARTIDRUGS.NS
# 9 AARTIIND.NS
# 10 AAVAS.NS
# 11 ABBOTINDIA.NS
# 12 ADANIENT.NS
# 13 ADANIGREEN.NS
# 14 ADANIPORTS.NS
# 15 ATGL.NS
# 16 ADANITRANS.NS
# 17 ABCAPITAL.NS
# 18 ABFRL.NS
# 19 ADVENZYMES.NS
# 20 AEGISCHEM.NS
# 21 AFFLE.NS
# 22 AJANTPHARM.NS
# 23 AKZOINDIA.NS
# 24 ALEMBICLTD.NS
# 25 APLLTD.NS
# APLLTD.NS  Errored out
# 26 ALKEM.NS
# 27 ALKYLAMINE.NS
# 28 ALOKINDS.NS
# 29 AMARAJABAT.NS
# 30 AMBER.NS
# 31 AMBUJACEM.NS
# 32 ANGELBRKG.NS
# ANGELBRKG.NS  Errored out
# 33 APOLLOHOSP.NS
# 34 APOLLOTYRE.NS
# 35 ASAHIINDIA.NS
# 36 ASHOKLEY.NS
# 37 ASHOKA.NS
# 38 ASIANPAINT.NS
# 39 ASTERDM.NS
# 40 ASTRAZEN.NS
# 41 ASTRAL.NS
# 42 ATUL.NS
# 43 AUROPHARMA.NS
# 44 AVANTIFEED.NS
# 45 DMART.NS
# 46 AXISBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 47 BASF.NS
# 48 BEML.NS
# 49 BSE.NS
# 50 BAJAJ-AUTO.NS
# 51 BAJAJCON.NS
# 52 BAJAJELEC.NS
# 53 BAJFINANCE.NS
# 54 BAJAJFINSV.NS
# 55 BAJAJHLDNG.NS
# 56 BALAMINES.NS
# 57 BALKRISIND.NS
# 58 BALMLAWRIE.NS
# 59 BALRAMCHIN.NS
# 60 BANDHANBNK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 61 BANKBARODA.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 62 BANKINDIA.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 63 MAHABANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 64 BATAINDIA.NS
# 65 BAYERCROP.NS
# 66 BERGEPAINT.NS
# BERGEPAINT.NS  Errored out
# 67 BDL.NS
# 68 BEL.NS
# 69 BHARATFORG.NS
# 70 BHEL.NS
# 71 BPCL.NS
# 72 BHARATRAS.NS
# BHARATRAS.NS  Errored out
# 73 BHARTIARTL.NS
# 74 BIOCON.NS
# 75 BIRLACORPN.NS
# 76 BSOFT.NS
# 77 BLISSGVS.NS
# 78 BLUEDART.NS
# 79 BLUESTARCO.NS
# 80 BBTC.NS
# 81 BOSCHLTD.NS
# 82 BRIGADE.NS
# 83 BRITANNIA.NS
# 84 BURGERKING.NS
# BURGERKING.NS  Errored out
# 85 CCL.NS
# 86 CESC.NS
# 87 CRISIL.NS
# 88 CSBBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 89 CADILAHC.NS
# CADILAHC.NS  Errored out
# 90 CANFINHOME.NS
# 91 CANBK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 92 CAPLIPOINT.NS
# 93 CGCL.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 94 CARBORUNIV.NS
# 95 CASTROLIND.NS
# 96 CEATLTD.NS
# 97 CENTRALBK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 98 CDSL.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 99 CENTURYPLY.NS
# 100 CENTURYTEX.NS
# 101 CERA.NS
# 102 CHALET.NS
# 103 CHAMBLFERT.NS
# 104 CHOLAHLDNG.NS
# 105 CHOLAFIN.NS
# 106 CIPLA.NS
# 107 CUB.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 108 COALINDIA.NS
# 109 COCHINSHIP.NS
# 110 COFORGE.NS
# 111 COLPAL.NS
# 112 CAMS.NS
# 113 CONCOR.NS
# 114 COROMANDEL.NS
# 115 CREDITACC.NS
# 116 CROMPTON.NS
# 117 CUMMINSIND.NS
# 118 CYIENT.NS
# 119 DCBBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 120 DCMSHRIRAM.NS
# 121 DLF.NS
# 122 DABUR.NS
# 123 DALBHARAT.NS
# 124 DEEPAKNTR.NS
# 125 DELTACORP.NS
# 126 DHANI.NS
# 127 DHANUKA.NS
# 128 DBL.NS
# 129 DISHTV.NS
# 130 DCAL.NS
# 131 DIVISLAB.NS
# 132 DIXON.NS
# 133 LALPATHLAB.NS
# 134 DRREDDY.NS
# 135 EIDPARRY.NS
# 136 EIHOTEL.NS
# 137 EPL.NS
# 138 EDELWEISS.NS
# 139 EICHERMOT.NS
# 140 ELGIEQUIP.NS
# 141 EMAMILTD.NS
# 142 ENDURANCE.NS
# 143 ENGINERSIN.NS
# 144 EQUITAS.NS
# 145 ERIS.NS
# 146 ESCORTS.NS
# 147 EXIDEIND.NS
# 148 FDC.NS
# 149 FEDERALBNK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 150 FINEORG.NS
# 151 FINCABLES.NS
# FINCABLES.NS  Errored out
# 152 FINPIPE.NS
# 153 FSL.NS
# 154 FORTIS.NS
# 155 FCONSUMER.NS
# 156 FRETAIL.NS
# 157 GAIL.NS
# 158 GEPIL.NS
# 159 GMMPFAUDLR.NS
# 160 GMRINFRA.NS
# 161 GALAXYSURF.NS
# 162 GRSE.NS
# 163 GARFIBRES.NS
# 164 GICRE.NS
# 165 GILLETTE.NS
# 166 GLAXO.NS
# 167 GLENMARK.NS
# 168 GODFRYPHLP.NS
# 169 GODREJAGRO.NS
# 170 GODREJCP.NS
# 171 GODREJIND.NS
# 172 GODREJPROP.NS
# 173 GRANULES.NS
# 174 GRAPHITE.NS
# 175 GRASIM.NS
# 176 GESHIP.NS
# 177 GREAVESCOT.NS
# 178 GRINDWELL.NS
# 179 GUJALKALI.NS
# 180 GAEL.NS
# 181 FLUOROCHEM.NS
# FLUOROCHEM.NS  Errored out
# 182 GUJGASLTD.NS
# 183 GNFC.NS
# 184 GPPL.NS
# 185 GSFC.NS
# 186 GSPL.NS
# 187 GULFOILLUB.NS
# 188 HEG.NS
# 189 HCLTECH.NS
# 190 HDFCAMC.NS
# 191 HDFCBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 192 HDFCLIFE.NS
# 193 HFCL.NS
# 194 HAPPSTMNDS.NS
# 195 HATSUN.NS
# 196 HAVELLS.NS
# 197 HEIDELBERG.NS
# 198 HEMIPROP.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:682: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DSO'] = (accounts_receivable/revenue)*term #DSO tells you how many days after the sale it takes people to pay you on average.
# HEMIPROP.NS  Errored out
# 199 HEROMOTOCO.NS
# 200 HSCL.NS
# 201 HINDALCO.NS
# 202 HAL.NS
# 203 HINDCOPPER.NS
# 204 HINDPETRO.NS
# 205 HINDUNILVR.NS
# 206 HINDZINC.NS
# 207 HONAUT.NS
# 208 HUDCO.NS
# 209 HDFC.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:682: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DSO'] = (accounts_receivable/revenue)*term #DSO tells you how many days after the sale it takes people to pay you on average.
# HDFC.NS  Errored out
# 210 HUHTAMAKI.NS
# 211 ICICIBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 212 ICICIGI.NS
# 213 ICICIPRULI.NS
# 214 ISEC.NS
# 215 IDBI.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 216 IDFCFIRSTB.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 217 IDFC.NS
# 218 IFBIND.NS
# 219 IIFL.NS
# 220 IIFLWAM.NS
# 221 IOLCP.NS
# 222 IRB.NS
# 223 IRCON.NS
# 224 ITC.NS
# 225 ITI.NS
# 226 INDIACEM.NS
# 227 IBULHSGFIN.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 228 IBREALEST.NS
# 229 INDIAMART.NS
# 230 INDIANB.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 231 IEX.NS
# IEX.NS  Errored out
# 232 INDHOTEL.NS
# 233 IOC.NS
# 234 IOB.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 235 IRCTC.NS
# 236 ICIL.NS
# 237 INDOCO.NS
# 238 IGL.NS
# 239 INDUSTOWER.NS
# 240 INDUSINDBK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 241 INFIBEAM.NS
# 242 NAUKRI.NS
# 243 INFY.NS
# 244 INGERRAND.NS
# 245 INOXLEISUR.NS
# 246 INTELLECT.NS
# 247 INDIGO.NS
# 248 IPCALAB.NS
# 249 JBCHEPHARM.NS
# 250 JKCEMENT.NS
# 251 JKLAKSHMI.NS
# 252 JKPAPER.NS
# 253 JKTYRE.NS
# 254 JMFINANCIL.NS
# 255 JSWENERGY.NS
# 256 JSWSTEEL.NS
# 257 JTEKTINDIA.NS
# 258 JAMNAAUTO.NS
# 259 JINDALSAW.NS
# 260 JSLHISAR.NS
# 261 JSL.NS
# JSL.NS  Errored out
# 262 JINDALSTEL.NS
# 263 JCHAC.NS
# 264 JUBLFOOD.NS
# 265 JUSTDIAL.NS
# 266 JYOTHYLAB.NS
# 267 KPRMILL.NS
# 268 KEI.NS
# 269 KNRCON.NS
# 270 KPITTECH.NS
# 271 KRBL.NS
# 272 KSB.NS
# 273 KAJARIACER.NS
# 274 KALPATPOWR.NS
# 275 KANSAINER.NS
# 276 KARURVYSYA.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 277 KSCL.NS
# 278 KEC.NS
# 279 KOTAKBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 280 L&TFH.NS
# 281 LTTS.NS
# 282 LICHSGFIN.NS
# 283 LAOPALA.NS
# 284 LAXMIMACH.NS
# 285 LTI.NS
# 286 LT.NS
# 287 LAURUSLABS.NS
# 288 LEMONTREE.NS
# 289 LINDEINDIA.NS
# 290 LUPIN.NS
# 291 LUXIND.NS
# 292 MASFIN.NS
# 293 MMTC.NS
# 294 MOIL.NS
# 295 MRF.NS
# 296 MGL.NS
# 297 MAHSCOOTER.NS
# 298 MAHSEAMLES.NS
# 299 M&MFIN.NS
# 300 M&M.NS
# 301 MAHINDCIE.NS
# 302 MHRIL.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:682: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DSO'] = (accounts_receivable/revenue)*term #DSO tells you how many days after the sale it takes people to pay you on average.
# MHRIL.NS  Errored out
# 303 MAHLOG.NS
# 304 MANAPPURAM.NS
# 305 MRPL.NS
# MRPL.NS  Errored out
# 306 MARICO.NS
# 307 MARUTI.NS
# 308 MFSL.NS
# 309 MAXHEALTH.NS
# 310 MAZDOCK.NS
# 311 METROPOLIS.NS
# 312 MINDTREE.NS
# 313 MINDACORP.NS
# 314 MINDAIND.NS
# 315 MIDHANI.NS
# 316 MOTHERSUMI.NS
# MOTHERSUMI.NS  Errored out
# 317 MOTILALOFS.NS
# 318 MPHASIS.NS
# 319 MCX.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 320 MUTHOOTFIN.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 321 NATCOPHARM.NS
# 322 NBCC.NS
# 323 NCC.NS
# 324 NESCO.NS
# 325 NHPC.NS
# 326 NLCINDIA.NS
# 327 NMDC.NS
# 328 NOCIL.NS
# 329 NTPC.NS
# 330 NH.NS
# 331 NATIONALUM.NS
# 332 NFL.NS
# 333 NAVINFLUOR.NS
# 334 NESTLEIND.NS
# 335 NETWORK18.NS
# 336 NILKAMAL.NS
# 337 NAM-INDIA.NS
# 338 OBEROIRLTY.NS
# 339 ONGC.NS
# 340 OIL.NS
# 341 OFSS.NS
# 342 ORIENTELEC.NS
# 343 ORIENTREF.NS
# ORIENTREF.NS  Errored out
# 344 PIIND.NS
# 345 PNBHOUSING.NS
# 346 PNCINFRA.NS
# 347 PVR.NS
# 348 PAGEIND.NS
# 349 PERSISTENT.NS
# 350 PETRONET.NS
# 351 PFIZER.NS
# 352 PHILIPCARB.NS
# PHILIPCARB.NS  Errored out
# 353 PHOENIXLTD.NS
# 354 PIDILITIND.NS
# 355 PEL.NS
# 356 POLYMED.NS
# 357 POLYCAB.NS
# 358 POLYPLEX.NS
# 359 PFC.NS
# 360 POWERGRID.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 361 PRESTIGE.NS
# 362 PRINCEPIPE.NS
# 363 PRSMJOHNSN.NS
# 364 PGHL.NS
# 365 PGHH.NS
# 366 PNB.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 367 QUESS.NS
# 368 RBLBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 369 RECLTD.NS
# 370 RITES.NS
# 371 RADICO.NS
# 372 RVNL.NS
# 373 RAIN.NS
# 374 RAJESHEXPO.NS
# 375 RALLIS.NS
# 376 RCF.NS
# 377 RATNAMANI.NS
# 378 RAYMOND.NS
# 379 REDINGTON.NS
# 380 RELAXO.NS
# 381 RELIANCE.NS
# 382 RESPONIND.NS
# 383 ROSSARI.NS
# 384 ROUTE.NS
# 385 SBICARD.NS
# 386 SBILIFE.NS
# 387 SIS.NS
# 388 SJVN.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 389 SKFINDIA.NS
# 390 SRF.NS
# 391 SANOFI.NS
# 392 SCHAEFFLER.NS
# 393 SCHNEIDER.NS
# 394 SEQUENT.NS
# 395 SHARDACROP.NS
# 396 SFL.NS
# 397 SHILPAMED.NS
# 398 SCI.NS
# 399 SHOPERSTOP.NS
# SHOPERSTOP.NS  Errored out
# 400 SHREECEM.NS
# 401 SHRIRAMCIT.NS
# 402 SRTRANSFIN.NS
# 403 SIEMENS.NS
# 404 SOBHA.NS
# 405 SOLARINDS.NS
# 406 SOLARA.NS
# 407 SONATSOFTW.NS
# 408 SPANDANA.NS
# 409 SPICEJET.NS
# 410 STARCEMENT.NS
# 411 SBIN.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 412 SAIL.NS
# 413 SWSOLAR.NS
# 414 STLTECH.NS
# 415 STAR.NS
# 416 SUDARSCHEM.NS
# 417 SUMICHEM.NS
# 418 SPARC.NS
# 419 SUNPHARMA.NS
# 420 SUNTV.NS
# 421 SUNCLAYLTD.NS
# 422 SUNDARMFIN.NS
# 423 SUNDRMFAST.NS
# 424 SUNTECK.NS
# 425 SUPRAJIT.NS
# 426 SUPREMEIND.NS
# 427 SUPPETRO.NS
# SUPPETRO.NS  Errored out
# 428 SUVENPHAR.NS
# 429 SUZLON.NS
# 430 SWANENERGY.NS
# 431 SYMPHONY.NS
# 432 SYNGENE.NS
# 433 TCIEXP.NS
# TCIEXP.NS  Errored out
# 434 TCNSBRANDS.NS
# 435 TTKPRESTIG.NS
# 436 TV18BRDCST.NS
# 437 TVSMOTOR.NS
# 438 TANLA.NS
# TANLA.NS  Errored out
# 439 TASTYBITE.NS
# 440 TATACHEM.NS
# 441 TATACOFFEE.NS
# 442 TATACOMM.NS
# 443 TCS.NS
# 444 TATACONSUM.NS
# 445 TATAELXSI.NS
# 446 TATAINVEST.NS
# 447 TATAMTRDVR.NS
# 448 TATAMOTORS.NS
# 449 TATAPOWER.NS
# 450 TATASTEEL.NS
# 451 TEAMLEASE.NS
# 452 TECHM.NS
# 453 NIACL.NS
# 454 RAMCOCEM.NS
# 455 THERMAX.NS
# 456 THYROCARE.NS
# 457 TIMKEN.NS
# 458 TITAN.NS
# 459 TORNTPHARM.NS
# 460 TORNTPOWER.NS
# 461 TRENT.NS
# 462 TRIDENT.NS
# 463 TRITURBINE.NS
# 464 TIINDIA.NS
# 465 UCOBANK.NS
# 466 UFLEX.NS
# 467 UPL.NS
# 468 UTIAMC.NS
# 469 UJJIVAN.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 470 UJJIVANSFB.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:692: RuntimeWarning: invalid value encountered in double_scalars
#   fr_dict['CCC'] = fr_dict['operating_cycle'] - fr_dict['DPO'] #The cash conversion cycle (CCC = DSO + DIO – DPO) measures the number of days a company's cash is tied up in the production and sales process of its operations and the benefit it derives from payment terms from its creditors. The shorter this cycle, the more liquid the company's working capital position is. The CCC is also known as the "cash" or "operating" cycle.
# 471 ULTRACEMCO.NS
# 472 UNIONBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 473 UBL.NS
# 474 MCDOWELL-N.NS
# 475 VGUARD.NS
# 476 VMART.NS
# 477 VIPIND.NS
# 478 VSTIND.NS
# 479 VAIBHAVGBL.NS
# 480 VAKRANGEE.NS
# 481 VALIANTORG.NS
# VALIANTORG.NS  Errored out
# 482 VTL.NS
# 483 VARROC.NS
# 484 VBL.NS
# 485 VEDL.NS
# 486 VENKEYS.NS
# 487 VINATIORGA.NS
# 488 IDEA.NS
# 489 VOLTAS.NS
# 490 WABCOINDIA.NS
# WABCOINDIA.NS  Errored out
# 491 WELCORP.NS
# 492 WELSPUNIND.NS
# 493 WESTLIFE.NS
# 494 WHIRLPOOL.NS
# WHIRLPOOL.NS  Errored out
# 495 WIPRO.NS
# 496 WOCKPHARMA.NS
# 497 YESBANK.NS
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:684: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DIO'] = (inventory/cogs)*term #DIO tells you how many days inventory sits on the shelf on average.
# E:\Stock Market Project\Stock-Scoring\helper_functions.py:689: RuntimeWarning: divide by zero encountered in double_scalars
#   fr_dict['DPO'] = (accounts_payable/cogs)*term #DPO tells you how many days the company takes to pay its suppliers.
# 498 ZEEL.NS
# 499 ZENSARTECH.NS
# 500 ZYDUSWELL.NS
# 501 ECLERX.NS
# Time taken :  2:47:19.332704

# %%
# Saving df
combined_financial_ratio_df.to_csv('annual_financial_ratio_n500.csv')

# %% [markdown]
# # Financial Ratio df (29/05/2021)

# %%
asdf = pd.read_csv('annual_financial_ratio_n500.csv', index_col=0)
asdf
# Out:
#                current_ratio         DSO         DIO  operating_cycle  \
# 3MINDIA.NS          3.204650   60.497955   93.335817       153.833772
# ABB.NS              1.657265  141.266686  153.559516       294.826202
# POWERINDIA.NS       1.148059  127.486706  240.500018       367.986725
# ACC.NS              1.726492   25.714586  109.147156       134.861742
# AIAENG.NS          12.259828   84.530146   39.904038       124.434184
# ...                      ...         ...         ...              ...
# YESBANK.NS          0.290472         NaN         inf              NaN
# ZEEL.NS             5.027557   77.439558   86.734063       164.173621
# ZENSARTECH.NS       2.726594   99.399241   34.499178       133.898420
# ZYDUSWELL.NS        1.061149   29.672714  133.950757       163.623471
# ECLERX.NS           4.206933   55.631816    4.756635        60.388451
#
#                       DPO         CCC  gross_profit_margin  \
# 3MINDIA.NS      93.335817   60.497955             0.368783
# ABB.NS         153.559516  141.266686             0.327680
# POWERINDIA.NS  240.500018  127.486706             0.364830
# ACC.NS         109.147156   25.714586             0.605604
# AIAENG.NS       39.904038   84.530146             0.495418
# ...                   ...         ...                  ...
# YESBANK.NS            inf         NaN             1.000000
# ZEEL.NS         86.734063   77.439558             0.295018
# ZENSARTECH.NS   34.499178   99.399241             0.211202
# ZYDUSWELL.NS   133.950757   29.672714             0.505938
# ECLERX.NS        4.756635   55.631816             0.408419
#
#                operating_profit_margin  pretax_profit_margin  \
# 3MINDIA.NS                    0.105089              0.110173
# ABB.NS                        0.065731              0.104452
# POWERINDIA.NS                 0.041779              0.057607
# ACC.NS                        0.148154              0.155178
# AIAENG.NS                     0.176313              0.219055
# ...                                ...                   ...
# YESBANK.NS                    0.170376              0.170376
# ZEEL.NS                       0.180262              0.172849
# ZENSARTECH.NS                 0.122367              0.135280
# ZYDUSWELL.NS                  0.160276              0.152317
# ECLERX.NS                     0.258009              0.259443
#
#                net_profit_margin  ...  fiftyTwoWeekLow  enterpriseToRevenue  \
# 3MINDIA.NS              0.081530  ...         17273.00                6.791
# ABB.NS                  0.074951  ...          1624.35                7.106
# POWERINDIA.NS           0.042384  ...          1747.65                3.352
# ACC.NS                  0.115343  ...          1900.00                2.212
# AIAENG.NS               0.173748  ...          1475.05                5.779
# ...                          ...  ...              ...                  ...
# YESBANK.NS              0.126450  ...            10.50                5.960
# ZEEL.NS                 0.117783  ...           166.80                2.748
# ZENSARTECH.NS           0.098096  ...           221.75                1.160
# ZYDUSWELL.NS            0.153736  ...          1430.00                4.980
# ECLERX.NS               0.193210  ...          1755.65                3.090
#
#                profitMargins  enterpriseToEbitda  trailing_EPS  forward_EPS  \
# 3MINDIA.NS           0.09224              52.877       286.240          NaN
# ABB.NS               0.06708              80.336        25.620        35.36
# POWERINDIA.NS        0.03660              60.238        47.990          NaN
# ACC.NS               0.08030              16.240        71.930       105.22
# AIAENG.NS            0.16917              28.196        70.060        82.69
# ...                      ...                 ...           ...          ...
# YESBANK.NS           0.12950                 NaN        -1.282         0.59
# ZEEL.NS              0.11778              13.068        12.054        16.46
# ZENSARTECH.NS        0.09810               7.898        18.596          NaN
# ZYDUSWELL.NS         0.14945              30.283        45.125          NaN
# ECLERX.NS            0.19321              10.104       105.055       132.35
#
#                bookValue  priceToBook       cmp  \
# 3MINDIA.NS      1938.357    11.602610  22490.00
# ABB.NS           196.738    14.202644   2794.20
# POWERINDIA.NS    267.102    12.163893   3249.00
# ACC.NS           737.304     3.043521   2244.00
# AIAENG.NS        504.062     5.068721   2554.95
# ...                  ...          ...       ...
# YESBANK.NS        13.559     1.132089     15.35
# ZEEL.NS          107.751     2.252879    242.75
# ZENSARTECH.NS    110.407     2.108109    232.75
# ZYDUSWELL.NS     735.497     2.175604   1600.15
# ECLERX.NS        502.183     4.398795   2209.00
#
#                                           Sector
# 3MINDIA.NS                        CONSUMER GOODS
# ABB.NS                  INDUSTRIAL MANUFACTURING
# POWERINDIA.NS           INDUSTRIAL MANUFACTURING
# ACC.NS                  CEMENT & CEMENT PRODUCTS
# AIAENG.NS               INDUSTRIAL MANUFACTURING
# ...                                          ...
# YESBANK.NS                    FINANCIAL SERVICES
# ZEEL.NS        MEDIA ENTERTAINMENT & PUBLICATION
# ZENSARTECH.NS                                 IT
# ZYDUSWELL.NS                      CONSUMER GOODS
# ECLERX.NS                                     IT
#
# [501 rows x 37 columns]

# %%
'''
ROCE d
operating profit margin d
EPS d
fixed asset turnover d
market_cap d
payoutRatio d

debt ratio a
PE a
enterpriseToEbitda(ev to ebitda) a
enterpriseToRevenue a

'''

imp_financial_df = asdf[['ROCE', 'debt_ratio', 'operating_profit_margin', 'net_profit_margin', 'trailing_PE', 'forward_PE',
                         'trailing_EPS', 'forward_EPS', 'enterpriseToEbitda', 'fixed_asset_turnover',
                         'enterpriseToRevenue', 'market_cap', 'payoutRatio', 'cmp', 'fiftyTwoWeekHigh', 
                         'fiftyTwoWeekLow', 'twoHundredDayAverage', 'fiftyDayAverage','Sector']].dropna(thresh=10)
imp_financial_df
# Out:
#                    ROCE  debt_ratio  operating_profit_margin  \
# 3MINDIA.NS     0.156118    0.273582                 0.105089
# ABB.NS         0.112014    0.498907                 0.065731
# POWERINDIA.NS  0.135998    0.678653                 0.041779
# ACC.NS         0.159181    0.319726                 0.148154
# AIAENG.NS      0.130419    0.070653                 0.176313
# ...                 ...         ...                      ...
# YESBANK.NS     0.000000    0.894221                 0.170376
# ZEEL.NS        0.133930    0.179523                 0.180262
# ZENSARTECH.NS  0.170749    0.305926                 0.122367
# ZYDUSWELL.NS   0.065378    0.149003                 0.160276
# ECLERX.NS      0.315256    0.242086                 0.258009
#
#                net_profit_margin  trailing_PE  forward_PE  trailing_EPS  \
# 3MINDIA.NS              0.081530    78.570435         NaN       286.240
# ABB.NS                  0.074951   109.063225   79.021490        25.620
# POWERINDIA.NS           0.042384    67.701600         NaN        47.990
# ACC.NS                  0.115343    31.196997   21.326744        71.930
# AIAENG.NS               0.173748    36.468030   30.897930        70.060
# ...                          ...          ...         ...           ...
# YESBANK.NS              0.126450          NaN   26.016950        -1.282
# ZEEL.NS                 0.117783    20.138544   14.747874        12.054
# ZENSARTECH.NS           0.098096    12.516132         NaN        18.596
# ZYDUSWELL.NS            0.153736    35.460390         NaN        45.125
# ECLERX.NS               0.193210    21.027080   16.690592       105.055
#
#                forward_EPS  enterpriseToEbitda  fixed_asset_turnover  \
# 3MINDIA.NS             NaN              52.877             10.114251
# ABB.NS               35.36              80.336              7.922398
# POWERINDIA.NS          NaN              60.238              5.245400
# ACC.NS              105.22              16.240              2.033941
# AIAENG.NS            82.69              28.196              3.648640
# ...                    ...                 ...                   ...
# YESBANK.NS            0.59                 NaN              3.930316
# ZEEL.NS              16.46              13.068             13.946848
# ZENSARTECH.NS          NaN               7.898             11.103611
# ZYDUSWELL.NS           NaN              30.283              7.836109
# ECLERX.NS           132.35              10.104             10.106357
#
#                enterpriseToRevenue    market_cap  payoutRatio       cmp  \
# 3MINDIA.NS                   6.791  2.533521e+11       0.0000  22490.00
# ABB.NS                       7.106  5.921133e+11       0.2030   2794.20
# POWERINDIA.NS                3.352  1.378067e+11       0.0417   3249.00
# ACC.NS                       2.212  4.220852e+11       0.8063   2244.00
# AIAENG.NS                    5.779  2.409839e+11       0.1285   2554.95
# ...                            ...           ...          ...       ...
# YESBANK.NS                   5.960  3.851238e+11       0.0000     15.35
# ZEEL.NS                      2.748  2.331653e+11       0.2490    242.75
# ZENSARTECH.NS                1.160  5.264339e+10       0.2135    232.75
# ZYDUSWELL.NS                 4.980  1.023728e+11       0.1010   1600.15
# ECLERX.NS                    3.090  7.476957e+10       0.0082   2209.00
#
#                fiftyTwoWeekHigh  fiftyTwoWeekLow  twoHundredDayAverage  \
# 3MINDIA.NS             27800.00         17273.00           22506.44100
# ABB.NS                  2850.00          1624.35            2267.11910
# POWERINDIA.NS           4042.60          1747.65            3055.67400
# ACC.NS                  2589.00          1900.00            2210.45070
# AIAENG.NS               2654.10          1475.05            1946.01980
# ...                         ...              ...                   ...
# YESBANK.NS                17.90            10.50              13.48600
# ZEEL.NS                  378.70           166.80             272.10100
# ZENSARTECH.NS            587.00           221.75             361.25476
# ZYDUSWELL.NS            2476.85          1430.00            1681.36880
# ECLERX.NS               2970.00          1755.65            2283.60720
#
#                fiftyDayAverage                             Sector
# 3MINDIA.NS           21944.275                     CONSUMER GOODS
# ABB.NS                2502.238           INDUSTRIAL MANUFACTURING
# POWERINDIA.NS         3290.533           INDUSTRIAL MANUFACTURING
# ACC.NS                2159.615           CEMENT & CEMENT PRODUCTS
# AIAENG.NS             2293.025           INDUSTRIAL MANUFACTURING
# ...                        ...                                ...
# YESBANK.NS              13.737                 FINANCIAL SERVICES
# ZEEL.NS                230.368  MEDIA ENTERTAINMENT & PUBLICATION
# ZENSARTECH.NS          261.919                                 IT
# ZYDUSWELL.NS          1594.374                     CONSUMER GOODS
# ECLERX.NS             2079.021                                 IT
#
# [477 rows x 19 columns]

# %%
imp_financial_df['Sector'].value_counts()
# Out:
# FINANCIAL SERVICES                   82
# CONSUMER GOODS                       65
# INDUSTRIAL MANUFACTURING             46
# PHARMA                               38
# AUTOMOBILE                           29
# IT                                   26
# CHEMICALS                            22
# CONSTRUCTION                         22
# METALS                               20
# SERVICES                             18
# CONSUMER SERVICES                    17
# OIL & GAS                            15
# CEMENT & CEMENT PRODUCTS             14
# POWER                                13
# FERTILISERS & PESTICIDES             12
# TEXTILES                             12
# HEALTHCARE SERVICES                  10
# MEDIA ENTERTAINMENT & PUBLICATION     7
# TELECOM                               7
# PAPER AND JUTE                        2
# Name: Sector, dtype: int64

# %% [markdown]
# # Creating Financial Ratio Score

# %%
asdf = pd.read_csv('annual_financial_ratio_n500.csv', index_col=0)
imp_financial_df = asdf[['ROCE', 'debt_ratio', 'operating_profit_margin', 'net_profit_margin', 'trailing_PE', 'forward_PE',
                         'trailing_EPS', 'forward_EPS', 'enterpriseToEbitda', 'fixed_asset_turnover',
                         'enterpriseToRevenue', 'market_cap', 'payoutRatio', 'cmp', 'fiftyTwoWeekHigh', 
                         'fiftyTwoWeekLow', 'twoHundredDayAverage', 'fiftyDayAverage','Sector']].dropna(thresh=10)

# Rank for higher the better metrics
for col in ['ROCE', 'operating_profit_margin', 'net_profit_margin', 'trailing_EPS', 'fixed_asset_turnover', 'market_cap', 'payoutRatio']:
    imp_financial_df['score_' + col] = imp_financial_df[col].rank()

# Rank for lower the better metrics    
for col in ['debt_ratio', 'trailing_PE', 'enterpriseToEbitda', 'enterpriseToRevenue']:
    imp_financial_df['score_' + col] = imp_financial_df[col].rank(ascending  = False)

# Custom ranks
imp_financial_df['score_close_to_52_week_high'] = (imp_financial_df['cmp'] / imp_financial_df['fiftyTwoWeekHigh']).rank(ascending  = False)
    

imp_financial_score_df = imp_financial_df.drop(columns = ['ROCE', 'debt_ratio', 'operating_profit_margin', 'net_profit_margin', 'trailing_PE', 'forward_PE',
                         'trailing_EPS', 'forward_EPS', 'enterpriseToEbitda', 'fixed_asset_turnover',
                         'enterpriseToRevenue', 'market_cap', 'payoutRatio', 'cmp', 'fiftyTwoWeekHigh', 
                         'fiftyTwoWeekLow', 'twoHundredDayAverage', 'fiftyDayAverage'])
imp_financial_score_df['final_score'] = imp_financial_score_df.drop(columns = ['Sector']).sum(axis = 1)

# %%
# Overall Sector Mean (Higher the better)
imp_financial_score_df.groupby(['Sector']).mean()['final_score'].sort_values()
# Out:
# Sector
# CONSUMER SERVICES                    1825.352941
# MEDIA ENTERTAINMENT & PUBLICATION    2088.785714
# TELECOM                              2239.285714
# PAPER AND JUTE                       2337.250000
# SERVICES                             2533.583333
# CONSTRUCTION                         2538.136364
# AUTOMOBILE                           2570.310345
# FINANCIAL SERVICES                   2595.725610
# TEXTILES                             2598.291667
# HEALTHCARE SERVICES                  2623.550000
# POWER                                2643.576923
# INDUSTRIAL MANUFACTURING             2644.500000
# CONSUMER GOODS                       2690.261538
# CHEMICALS                            2785.045455
# PHARMA                               2811.289474
# CEMENT & CEMENT PRODUCTS             2877.964286
# FERTILISERS & PESTICIDES             2971.666667
# METALS                               3281.450000
# OIL & GAS                            3359.133333
# IT                                   3433.807692
# Name: final_score, dtype: float64

# %%
imp_financial_score_df.sort_values('final_score', ascending=False).head(50)
# Out:
#                                           Sector  score_ROCE  \
# OFSS.NS                                       IT       438.0
# NMDC.NS                                   METALS       442.0
# HDFCAMC.NS                    FINANCIAL SERVICES       443.0
# VEDL.NS                                   METALS       418.0
# HINDZINC.NS                               METALS       450.0
# NATIONALUM.NS                             METALS       409.0
# TATAINVEST.NS                 FINANCIAL SERVICES        95.0
# SANOFI.NS                                 PHARMA       436.0
# UTIAMC.NS                     FINANCIAL SERVICES       310.0
# NAM-INDIA.NS                  FINANCIAL SERVICES       421.0
# BAJAJ-AUTO.NS                         AUTOMOBILE       346.0
# SUNTV.NS       MEDIA ENTERTAINMENT & PUBLICATION       390.0
# TECHM.NS                                      IT       341.0
# VTL.NS                                  TEXTILES       352.0
# THYROCARE.NS                 HEALTHCARE SERVICES       453.0
# CASTROLIND.NS                          OIL & GAS       465.0
# MPHASIS.NS                                    IT       377.0
# OIL.NS                                 OIL & GAS       291.0
# FINPIPE.NS              INDUSTRIAL MANUFACTURING       369.0
# LUXIND.NS                               TEXTILES       447.0
# BAJAJCON.NS                       CONSUMER GOODS       351.0
# TCS.NS                                        IT       462.0
# SAIL.NS                                   METALS       354.0
# LTI.NS                                        IT       425.0
# WIPRO.NS                                      IT       309.0
# PFIZER.NS                                 PHARMA       386.0
# MINDTREE.NS                                   IT       444.0
# ECLERX.NS                                     IT       439.0
# GNFC.NS                                CHEMICALS       365.0
# JSLHISAR.NS                               METALS       441.0
# TATASTEEL.NS                              METALS       428.0
# MGL.NS                                 OIL & GAS       320.0
# LTTS.NS                                       IT       397.0
# GAIL.NS                                OIL & GAS       279.0
# JINDALSTEL.NS                             METALS       399.0
# JSWSTEEL.NS                               METALS       392.0
# CAMS.NS                       FINANCIAL SERVICES       460.0
# SUPREMEIND.NS           INDUSTRIAL MANUFACTURING       405.0
# CYIENT.NS                                     IT       316.0
# NAUKRI.NS                      CONSUMER SERVICES       104.0
# HCLTECH.NS                                    IT       378.0
# ZEEL.NS        MEDIA ENTERTAINMENT & PUBLICATION       246.0
# DEEPAKNTR.NS                           CHEMICALS       455.0
# DIVISLAB.NS                               PHARMA       432.0
# BPCL.NS                                OIL & GAS       245.0
# ZENSARTECH.NS                                 IT       303.0
# ABBOTINDIA.NS                             PHARMA       449.0
# BSOFT.NS                                      IT       350.0
# POLYPLEX.NS             INDUSTRIAL MANUFACTURING       311.0
# AUROPHARMA.NS                             PHARMA       234.0
#
#                score_operating_profit_margin  score_net_profit_margin  \
# OFSS.NS                                440.0                    438.0
# NMDC.NS                                442.0                    440.0
# HDFCAMC.NS                             470.0                    468.0
# VEDL.NS                                392.0                    302.0
# HINDZINC.NS                            439.0                    432.0
# NATIONALUM.NS                          386.0                    383.0
# TATAINVEST.NS                          474.0                    474.0
# SANOFI.NS                              369.0                    426.0
# UTIAMC.NS                              445.0                    448.0
# NAM-INDIA.NS                           464.0                    459.0
# BAJAJ-AUTO.NS                          307.0                    359.0
# SUNTV.NS                               451.0                    457.0
# TECHM.NS                               241.0                    279.0
# VTL.NS                                 326.0                    334.0
# THYROCARE.NS                           415.0                    421.0
# CASTROLIND.NS                          371.0                    361.0
# MPHASIS.NS                             249.0                    274.0
# OIL.NS                                 399.0                    368.0
# FINPIPE.NS                             332.0                    394.0
# LUXIND.NS                              327.0                    311.0
# BAJAJCON.NS                            323.0                    369.0
# TCS.NS                                 384.0                    378.0
# SAIL.NS                                270.0                    271.0
# LTI.NS                                 294.0                    307.0
# WIPRO.NS                               281.0                    320.0
# PFIZER.NS                              393.0                    398.0
# MINDTREE.NS                            314.0                    325.0
# ECLERX.NS                              385.0                    371.0
# GNFC.NS                                375.0                    376.0
# JSLHISAR.NS                            212.0                    285.0
# TATASTEEL.NS                           359.0                    338.0
# DIVISLAB.NS                         59.0                        334.0
# BPCL.NS                            457.0                        354.0
# ZENSARTECH.NS                      387.0                        466.0
# ABBOTINDIA.NS                      101.0                        218.0
# BSOFT.NS                           314.5                        425.0
# POLYPLEX.NS                        369.0                        231.0
# AUROPHARMA.NS                      378.0                        234.0
#
#                final_score
# OFSS.NS             4595.0
# NMDC.NS             4422.0
# HDFCAMC.NS          4289.0
# VEDL.NS             4244.0
# HINDZINC.NS         4206.0
# NATIONALUM.NS       4075.0
# TATAINVEST.NS       4059.0
# SANOFI.NS           4054.0
# UTIAMC.NS           4044.0
# NAM-INDIA.NS        4030.0
# BAJAJ-AUTO.NS       4004.0
# SUNTV.NS            3985.0
# TECHM.NS            3980.5
# VTL.NS              3917.0
# THYROCARE.NS        3854.0
# CASTROLIND.NS       3838.0
# MPHASIS.NS          3835.0
# OIL.NS              3829.0
# FINPIPE.NS          3826.0
# LUXIND.NS           3815.0
# BAJAJCON.NS         3814.5
# TCS.NS              3807.0
# SAIL.NS             3805.0
# LTI.NS              3795.0
# WIPRO.NS            3780.5
# PFIZER.NS           3775.0
# MINDTREE.NS         3768.0
# ECLERX.NS           3743.0
# GNFC.NS             3728.0
# JSLHISAR.NS         3718.0
# TATASTEEL.NS        3710.0
# MGL.NS              3705.0
# LTTS.NS             3686.5
# GAIL.NS             3684.0
# JINDALSTEL.NS       3681.0
# JSWSTEEL.NS         3670.0
# CAMS.NS             3668.0
# SUPREMEIND.NS       3648.0
# CYIENT.NS           3647.0
# NAUKRI.NS           3621.0
# HCLTECH.NS          3609.0
# ZEEL.NS             3607.5
# DEEPAKNTR.NS        3607.0
# DIVISLAB.NS         3604.5
# BPCL.NS             3597.0
# ZENSARTECH.NS       3581.0
# ABBOTINDIA.NS       3574.0
# BSOFT.NS            3561.5
# POLYPLEX.NS         3560.0
# AUROPHARMA.NS       3559.0

# %%
req_sector = 'PHARMA'
req_index = imp_financial_score_df[imp_financial_score_df['Sector'] == req_sector].sort_values('final_score', ascending=False).index
asdf[['ROCE', 'debt_ratio', 'operating_profit_margin', 'net_profit_margin', 'trailing_PE', 'forward_PE',
                         'trailing_EPS', 'forward_EPS', 'enterpriseToEbitda', 'fixed_asset_turnover',
                         'enterpriseToRevenue', 'market_cap', 'payoutRatio', 'cmp', 'fiftyTwoWeekHigh', 
                         'fiftyTwoWeekLow', 'twoHundredDayAverage', 'fiftyDayAverage','Sector']].dropna(thresh=10).loc[req_index]
# Out:
#                    ROCE  debt_ratio  operating_profit_margin  \
# SANOFI.NS      0.301073    0.272917                 0.235372
# PFIZER.NS      0.236489    0.265632                 0.276037
# DIVISLAB.NS    0.293335    0.123108                 0.398728
# ABBOTINDIA.NS  0.339558    0.332455                 0.208523
# AUROPHARMA.NS  0.128327    0.275566                 0.140966
# GLAXO.NS       0.238116    0.425254                 0.213187
# ALKEM.NS       0.188173    0.371156                 0.163925
# PGHL.NS        0.292871    0.286414                 0.216936
# AJANTPHARM.NS  0.241524    0.195099                 0.246382
# FDC.NS                  0.141633    15.353418   21.370968        17.260
# ALEMBICLTD.NS           2.838916     5.663418         NaN        12.722
# NATCOPHARM.NS           0.087413    46.143417   15.669978        14.015
# SEQUENT.NS              0.029198    37.139380   34.467743         2.877
# BIOCON.NS               0.079228    57.737984   28.836885         5.389
# ASTRAZEN.NS             0.076465    89.987330         NaN        33.962
# SOLARA.NS              -0.045847     7.024138         NaN        54.811
# LUPIN.NS               -0.093142          NaN   16.716492       -14.480
# SHILPAMED.NS            0.052956    86.085830         NaN         4.614
# ERIS.NS                 0.000000    24.534018         NaN        28.220
# DCAL.NS                 0.008413          NaN         NaN        -7.891
# WOCKPHARMA.NS          -0.075542          NaN         NaN        -5.122
# STAR.NS                -0.149894          NaN   14.001604       -31.647
# SPARC.NS               -1.481967          NaN         NaN        -9.197
#
#                forward_EPS  enterpriseToEbitda  fixed_asset_turnover  \
# SANOFI.NS           160.60              20.679              8.652619
# PFIZER.NS           103.63              21.144             11.864361
# DIVISLAB.NS          56.30              25.260              1.871528
# ABBOTINDIA.NS          NaN              35.489             18.702315
# AUROPHARMA.NS        62.29               7.036              2.199090
# GLAXO.NS             57.13              28.111             10.072384
# ALKEM.NS            101.46              19.942              3.844707
# PGHL.NS                NaN              27.208              7.205729
# AJANTPHARM.NS        99.28              17.501              2.028013
# CAPLIPOINT.NS          NaN              13.707              4.325814
# IOLCP.NS               NaN               7.732              3.296684
# IPCALAB.NS           35.08              19.532              2.329777
# GLENMARK.NS          42.48               5.491              2.704323
# DRREDDY.NS          113.45              14.303              3.448519
# SUVENPHAR.NS           NaN              20.274              2.349353
# JBCHEPHARM.NS          NaN              25.169              4.276951
# SUNPHARMA.NS         32.68              21.316              3.460907
# CIPLA.NS             41.50              17.912              3.880269
# TORNTPHARM.NS          NaN              22.709              2.620334
# LAURUSLABS.NS        23.37              20.199              1.538251
# BLISSGVS.NS            NaN               7.004              2.535258
# GRANULES.NS            NaN              11.117              2.359506
# INDOCO.NS            11.53              11.487              2.635292
# AARTIDRUGS.NS          NaN              13.919              3.246696
# FDC.NS               12.40              14.832              1.897452
# ALEMBICLTD.NS          NaN             112.742              0.263057
# NATCOPHARM.NS        41.27              45.738              0.842488
# SEQUENT.NS            3.10              32.290              4.342543
# BIOCON.NS            10.79              20.252              0.873957
# ASTRAZEN.NS            NaN              87.360             10.504629
# SOLARA.NS              NaN              29.379              1.115132
# LUPIN.NS             40.81              16.067              3.039572
# SHILPAMED.NS           NaN              20.671              0.816105
# ERIS.NS                NaN              18.754                   NaN
# DCAL.NS                NaN              10.102              0.768131
# WOCKPHARMA.NS          NaN              23.980              1.129371
# STAR.NS              24.94              27.700              2.028383
# SPARC.NS               NaN             -32.531              1.442914
#
#                enterpriseToRevenue    market_cap  payoutRatio       cmp  \
# SANOFI.NS                    4.884  1.468825e+11       0.4258   6375.00
# PFIZER.NS                    6.768  1.932383e+11       0.2241   4224.00
# DIVISLAB.NS                 10.939  9.878367e+11       0.1793   3721.10
# ABBOTINDIA.NS                7.461  4.009743e+11       0.3154  18870.00
# AUROPHARMA.NS                1.293  3.473153e+11       0.0996    592.75
# GLAXO.NS                     6.450  2.441393e+11       2.6076   1438.00
# ALKEM.NS                     3.773  3.530814e+11       0.2543   2953.05
# PGHL.NS                      6.473  7.266043e+10       0.3568   4375.00
# AJANTPHARM.NS                4.622  1.107176e+11       0.1147   1278.00
# CAPLIPOINT.NS                4.262  6.002033e+10       0.0764    792.15
# IOLCP.NS                     0.914  2.078468e+10       0.2101    354.05
# IPCALAB.NS                   4.271  1.176775e+11       0.1148    927.50
# GLENMARK.NS                  1.095  1.094953e+11       0.0749    388.05
# DRREDDY.NS                   3.093  7.060151e+11       0.1399   4256.00
# SUVENPHAR.NS                 8.899  1.158525e+11       0.1122    455.10
# JBCHEPHARM.NS                5.642  1.451463e+11       0.3312   1849.85
# SUNPHARMA.NS                 5.484  2.221716e+12       0.6618    913.70
# CIPLA.NS                     3.644  8.348994e+11       0.1604   1028.00
# TORNTPHARM.NS                6.325  2.608742e+11       0.8709   1541.60
# LAURUSLABS.NS                5.734  3.044139e+11       0.1288    566.50
# BLISSGVS.NS                  1.092  7.941734e+09       0.3497     76.60
# GRANULES.NS                  2.163  7.688186e+10       0.0904    310.00
# INDOCO.NS                    2.458  3.487247e+10       0.0893    378.00
# AARTIDRUGS.NS                1.769  3.974393e+10       0.0485    429.00
# FDC.NS                       2.463  4.481600e+10       0.0000    265.00
# ALEMBICLTD.NS               20.064  1.850114e+10       0.0231     72.05
# NATCOPHARM.NS                6.197  1.186578e+11       0.4828    646.70
# SEQUENT.NS                   2.500  2.656291e+10       0.3010    106.85
# BIOCON.NS                    4.656  3.735667e+11       0.0845    311.15
# ASTRAZEN.NS                  8.965  7.717726e+10       0.0813   3056.15
# SOLARA.NS                    1.852  1.383933e+10          NaN    385.00
# LUPIN.NS                     1.925  3.139075e+11          NaN    682.20
# SHILPAMED.NS                 3.679  3.450385e+10       0.1515    397.20
# ERIS.NS                      6.858  9.411113e+10       0.2011    692.35
# DCAL.NS                      1.564  1.792030e+10       0.0000    114.30
# WOCKPHARMA.NS                1.678  2.625785e+10       0.0000    236.95
# STAR.NS                      0.896  3.135212e+10          NaN    349.20
# SPARC.NS                    44.264  5.728763e+10       0.0000    217.45
#
#                fiftyTwoWeekHigh  fiftyTwoWeekLow  twoHundredDayAverage  \
# SANOFI.NS               9090.00        6328.0000            7195.48930
# PFIZER.NS               6175.00        4060.0000            4508.83150
# DIVISLAB.NS             5425.10        3365.5500            4227.15670
# ABBOTINDIA.NS          23934.45       15514.0000           18112.45300
# AUROPHARMA.NS            768.45         503.4500             626.23020
# GLAXO.NS                1918.75        1372.0500            1592.05940
# ALKEM.NS                4070.00        2828.0000            3323.27080
# PGHL.NS                 5851.75        3901.0500            4639.22000
# AJANTPHARM.NS           1577.20        1061.7667            1287.85160
# CAPLIPOINT.NS           1008.40         626.0000             766.14250
# IOLCP.NS                 626.90         292.8000             409.17126
# IPCALAB.NS              1383.10         831.0500             996.99475
# GLENMARK.NS              583.00         348.5000             447.57600
